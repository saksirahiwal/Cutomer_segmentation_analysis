# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Mall_Customers.csv')

# %%
data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.shape
# Out:
# (200, 5)

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as msno

# %%
msno.matrix(data)
# Out:
# <Axes: >

# %% [markdown]
# # Data visulization & EDA

# %%
data.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.distplot(data['Age'])
plt.title("Distribution of Age")
plt.xlabel("Range of Age")
plt.ylabel("count")

plt.subplot(1,3,2)
sns.distplot(data['Annual Income (k$)'])
plt.title("Distribution of Income")
plt.xlabel("Range of Income")
plt.ylabel("count")

plt.subplot(1,3,3)
sns.distplot(data['Spending Score (1-100)'])
plt.title("Distribution of Score")
plt.xlabel("Range of score")
plt.ylabel("count")
# Out:
# C:\Users\saksh\AppData\Local\Temp\ipykernel_23120\1602638812.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'])
# C:\Users\saksh\AppData\Local\Temp\ipykernel_23120\1602638812.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df=data.groupby('Genre').size()

df.plot(kind='pie',subplots=True ,
        colors=['lightgreen','orange'],
        explode=[0,0.001],
        labels=['Female','Male'],
        autopct='%.2f%%')
plt.title("Gender Distribution")
plt.ylabel("")
plt.show()

# %%
data.hist(figsize=(12,7))
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
data=data.rename(columns={'Genre':'Gender'})

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
sns.pairplot(data,vars=['Age', 'Annual Income (k$)',
       'Spending Score (1-100)'],hue='Gender')

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='Age',data=data)
plt.title("Distribution of Age")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='Annual Income (k$)',data=data)
plt.title("Distribution of Annual Income")
# Out:
# Text(0.5, 1.0, 'Distribution of Annual Income')

# %%
plt.figure(figsize=(20,8))
sns.countplot(x='Spending Score (1-100)',data=data)
plt.title("Distribution of score")
# Out:
# Text(0.5, 1.0, 'Distribution of score')

# %%
# !pip install dabl
# Out:
# ...
#   Obtaining dependency information for dabl from https://files.pythonhosted.org/packages/60/7e/1d2ea0b36f30b68bf1d3499498e96761f2f1d2eff50d4f9d47465a1f067e/dabl-0.3.1-py3-none-any.whl.metadata
#   Using cached dabl-0.3.1-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Obtaining dependency information for matplotlib>=3.8 from https://files.pythonhosted.org/packages/8b/ce/15b0bb2fb29b3d46211d8ca740b96b5232499fc49200b58b8d571292c9a6/matplotlib-3.9.2-cp311-cp311-win_amd64.whl.metadata
#   Using cached matplotlib-3.9.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# ...
# Using cached dabl-0.3.1-py3-none-any.whl (558 kB)
# Using cached matplotlib-3.9.2-cp311-cp311-win_amd64.whl (7.8 MB)
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\saksh\anaconda3\Anoconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\saksh\anaconda3\Anoconda\Lib\site-packages)
# ...

# %%
import dabl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 import dabl
#
# ModuleNotFoundError: No module named 'dabl'

# %%
pip install matplotlib --user
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install dabl
# Out:
# ...
#   Obtaining dependency information for dabl from https://files.pythonhosted.org/packages/60/7e/1d2ea0b36f30b68bf1d3499498e96761f2f1d2eff50d4f9d47465a1f067e/dabl-0.3.1-py3-none-any.whl.metadata
#   Using cached dabl-0.3.1-py3-none-any.whl.metadata (5.2 kB)
# ...
# Using cached dabl-0.3.1-py3-none-any.whl (558 kB)
# ...

# %%
import dabl

# %%
dabl.plot(data ,target_col='Age')
# Out:
# Target looks like regression
# [<Axes: title={'center': 'Target distribution'}, xlabel='Age', ylabel='frequency'>,
#  array([[<Axes: title={'center': 'F=-3.45E-01'}, xlabel='Spending Score (1-100)', ylabel='Age'>,
#          <Axes: title={'center': 'F=1.98E-02'}, xlabel='Annual Income (k$)'>]],
#        dtype=object),
#  array([[<Axes: title={'center': 'F=8.01E-02'}, xlabel='Age', ylabel='Gender'>]],
#        dtype=object)]

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
dabl.plot(data ,target_col='Annual Income (k$)')
# Out:
# Target looks like regression
# [<Axes: title={'center': 'Target distribution'}, xlabel='Annual Income (k$)', ylabel='frequency'>,
#  array([[<Axes: title={'center': 'F=1.98E-02'}, xlabel='Age', ylabel='Annual Income (k$)'>,
#          <Axes: title={'center': 'F=7.84E-03'}, xlabel='Spending Score (1-100)'>]],
#        dtype=object),
#  array([[<Axes: title={'center': 'F=0.00E+00'}, xlabel='Annual Income (k$)', ylabel='Gender'>]],
#        dtype=object)]

# %%
sns.heatmap(data.corr(),cmap='Wistia',annot=True)
plt.show()
# Out:
# C:\Users\saksh\AppData\Local\Temp\ipykernel_23120\1611106169.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),cmap='Wistia',annot=True)

# %%
plt.figure(figsize=(15,6))
for gender in ['Male','Female']:
    plt.scatter(x='Age',y='Annual Income (k$)',alpha=0.5,s=200,label=gender,
               data=data[data['Gender']==gender])
    
plt.xlabel('Age')
plt.ylabel('Annual Income (k$)')
plt.title('Age vs Annual Income (k$)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,6))
for gender in ['Male','Female']:
    plt.scatter(x='Annual Income (k$)',y='Spending Score (1-100)',alpha=0.5,s=200,
             label=gender,  data=data[data['Gender']==gender])
    
plt.xlabel('Annual Income')
plt.ylabel('Spending Score (1-100)')
plt.title('Annual Income (k$) vs spending score')
plt.legend()
plt.show()

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
x=data.iloc[:,[3,4]].values

# %%
x
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import KMeans

# %%
k=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans.fit(x)
    k.append(kmeans.inertia_)
# Out:
# C:\Users\saksh\anaconda3\Anoconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\saksh\anaconda3\Anoconda\Lib\site-packages\joblib\externals\loky\backend\context.py:110: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\saksh\anaconda3\Anoconda\Lib\site-packages\joblib\externals\loky\backend\context.py", line 199, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\saksh\anaconda3\Anoconda\Lib\subprocess.py", line 548, in run
# ...

# %%
plt.plot(range(1,11),k)
plt.show()

# %%
model=KMeans(n_clusters=5,init='k-means++',random_state=0)
y_kmeans=model.fit_predict(x)
# Out:
# C:\Users\saksh\anaconda3\Anoconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\saksh\anaconda3\Anoconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.figure(figsize=(15,8))
plt.scatter(x[y_kmeans==0,0],x[y_kmeans==0,1],s=100,c='magenta',label='Cluster1')
plt.scatter(x[y_kmeans==1,0],x[y_kmeans==1,1],s=100,c='blue',label='Cluster2')
plt.scatter(x[y_kmeans==2,0],x[y_kmeans==2,1],s=100,c='cyan',label='Cluster3')
plt.scatter(x[y_kmeans==3,0],x[y_kmeans==3,1],s=100,c='green',label='Cluster4')
plt.scatter(x[y_kmeans==4,0],x[y_kmeans==4,1],s=100,c='red',label='Cluster5')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=200,c='black',label='Centriods')
plt.title('K Means Clustering Algorithim')
plt.xlabel('Annual Incomw (k$)')
plt.ylabel('Spending score (1-100)')
plt.legend()
plt.show()

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
z=data.iloc[:,[2,4]].values

# %%
z
# Out:
# array([[19, 39],
#        [21, 81],
#        [20,  6],
#        [23, 77],
#        [31, 40],
#        [22, 76],
#        [35,  6],
#        [23, 94],
#        [64,  3],
#        [30, 72],
#        [67, 14],
#        [35, 99],
#        [58, 15],
#        [24, 77],
#        [37, 13],
#        [22, 79],
#        [35, 35],
#        [20, 66],
#        [52, 29],
#        [35, 98],
#        [35, 35],
#        [25, 73],
#        [46,  5],
#        [31, 73],
#        [54, 14],
#        [29, 82],
#        [45, 32],
#        [35, 61],
#        [40, 31],
#        [23, 87],
#        [60,  4],
#        [21, 73],
#        [53,  4],
#        [18, 92],
#        [49, 14],
#        [21, 81],
#        [42, 17],
#        [30, 73],
#        [36, 26],
#        [20, 75],
#        [65, 35],
#        [24, 92],
#        [48, 36],
#        [31, 61],
#        [49, 28],
#        [24, 65],
#        [50, 55],
#        [27, 47],
#        [29, 42],
#        [31, 42],
#        [49, 52],
#        [33, 60],
# ...

# %%
f=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans.fit(z)
    f.append(kmeans.inertia_)
# Out:
# C:\Users\saksh\anaconda3\Anoconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\saksh\anaconda3\Anoconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\saksh\anaconda3\Anoconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
plt.plot(range(1,11),f)
plt.show()

# %%
model1=KMeans(n_clusters=3,init='k-means++',random_state=0)
y_kmeans1=model1.fit_predict(x)
# Out:
# C:\Users\saksh\anaconda3\Anoconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\saksh\anaconda3\Anoconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.figure(figsize=(15,8))
plt.scatter(z[y_kmeans1==0,0],z[y_kmeans1==0,1],s=100,c='magenta',label='Cluster1')
plt.scatter(z[y_kmeans1==1,0],z[y_kmeans1==1,1],s=100,c='blue',label='Cluster2')
plt.scatter(z[y_kmeans1==2,0],z[y_kmeans1==2,1],s=100,c='cyan',label='Cluster3')
##plt.scatter(z[y_kmeans1==3,0],z[y_kmeans1==3,1],s=100,c='green',label='Cluster4')

plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=200,c='black',label='Centriods')
plt.title('K Means Clustering Algorithim')
plt.xlabel('Age')
plt.ylabel('Spending score (1-100)')
plt.legend()
plt.show()
